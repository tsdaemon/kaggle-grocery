# %%
import pandas as pd
import lightgbm as lgb
from date import *
from importlib import reload
import model
reload(model)
from model import *
from metric import get_weights, NWRMSLE_log
import numpy as np

# %%
df = load_data_in_date_range('./data/train_processed.csv', '2017-05-01', '2017-08-15', 110000000)
# Out:
# Reading batch from position 110000000, batch size 10000000...
# Filtering 10000000...
# Filtered 5823749, mapping...
# Mapped, reducing...
# Batch done.
# ================================================================================
# Reading batch from position 120000000, batch size 10000000...
# Filtering 5497041...
# Filtered 5497041, mapping...
# Mapped, reducing...
# Batch done.
# End of dataset is found.

# %%
# log target
df = convert_unit_sales(df)

# %%
items.head()
# Out:
#    item_nbr        family  class  perishable  weight
# 0     96995     GROCERY I   1093           0    1.00
# 1     99197     GROCERY I   1067           0    1.00
# 2    103501      CLEANING   3008           0    1.00
# 3    103520     GROCERY I   1028           0    1.00
# 4    103665  BREAD/BAKERY   2712           1    1.25

# %%
items = pd.read_csv('./data/items_encoded.csv')
stores = pd.read_csv('./data/stores_encoded.csv')

# %%
# !telegram-send "Data is ready"

# %%
folds = [('2017-05-01', '2017-06-15', '2017-06-16', '2017-06-30'),
         ('2017-05-16', '2017-06-30', '2017-07-01', '2017-07-15'),
         ('2017-06-01', '2017-07-15', '2017-07-16', '2017-07-31'),
         ('2017-06-16', '2017-07-31', '2017-08-01', '2017-08-15')]

param = {
    'num_leaves':30,
    'objective':'regression_l2',
    'metric':'l2_root',
    'num_threads':4
        }
results = []

for train_start, train_end, test_start, test_end in folds:
    print("Extracting fold...")
    train, test = extract_train_test(df,  train_start, train_end, test_start, test_end)
    
    print("Preparing train...")
    train = fill_empty_sales(train)
    train, ext_cols = extend_dataset(train, items, stores)
    x_cols = ext_cols + ['onpromotion']
    train_X = train[x_cols]
    train_y = train['unit_sales']
    train_weights = get_weights(train['item_nbr'])
    train_dataset = lgb.Dataset(train_X, label=train_y, weight=train_weights)
    #del train
    
    print("Preparing test...")
    test = fill_empty_sales(test)
    test, _ = extend_dataset(test, items, stores)
    test_X = test[x_cols]
    test_y = test['unit_sales']
    test_weights = get_weights(test['item_nbr'])
    test_dataset = lgb.Dataset(test_X, label=test_y, weight=test_weights, reference=train_dataset)
    #del test
    
    print("Training!")
    bst = lgb.train(param, 
                    train_dataset, 
                    200,
                    valid_sets=[test_dataset], 
                    early_stopping_rounds=10, 
                    verbose_eval=True, 
                    feature_name=x_cols, 
                    categorical_feature=ext_cols)
    
    test_y_pred = bst.predict(test_X)
    error = NWRMSLE_log(test_y_pred, test_y, test_weights)
    print('Validation error: {}'.format(error))
    
    results.append((bst.best_iteration, error))
# Out:
# Extracting fold...
# Preparing train...
# Preparing test...
# Training!
# C:\Users\Anatoliy\Anaconda2\envs\py35\lib\site-packages\lightgbm\basic.py:1007: UserWarning: categorical_feature in Dataset is overrided. New categorical_feature is ['city', 'class', 'cluster', 'family', 'perishable', 'salary', 'state', 'type', 'weekday', 'weekend']
#   warnings.warn('categorical_feature in Dataset is overrided. New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# [1]	valid_0's rmse: 1.01825
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0
# [159]	valid_0's rmse: 0.918441
# [160]	valid_0's rmse: 0.918424
# [161]	valid_0's rmse: 0.918417
# [162]	valid_0's rmse: 0.918418
# [163]	valid_0's rmse: 0.918399
# [164]	valid_0's rmse: 0.918381
# [165]	valid_0's rmse: 0.918359
# [166]	valid_0's rmse: 0.918352
# [167]	valid_0's rmse: 0.918336
# [168]	valid_0's rmse: 0.918322
# [169]	valid_0's rmse: 0.918314
# [170]	valid_0's rmse: 0.918317
# [171]	valid_0's rmse: 0.918304
# [172]	valid_0's rmse: 0.9183
# [173]	valid_0's rmse: 0.918308
# [174]	valid_0's rmse: 0.918301
# [175]	valid_0's rmse: 0.918289
# [176]	valid_0's rmse: 0.918271
# [177]	valid_0's rmse: 0.918253
# [178]	valid_0's rmse: 0.918239
# [179]	valid_0's rmse: 0.918233
# [180]	valid_0's rmse: 0.918221
# [181]	valid_0's rmse: 0.918215
# [182]	valid_0's rmse: 0.9182
# [183]	valid_0's rmse: 0.918193
# [184]	valid_0's rmse: 0.918187
# [185]	valid_0's rmse: 0.918153
# [186]	valid_0's rmse: 0.918135
# [187]	valid_0's rmse: 0.91813
# [188]	valid_0's rmse: 0.918109
# [189]	valid_0's rmse: 0.918102
# [190]	valid_0's rmse: 0.918082
# [191]	valid_0's rmse: 0.918091
# [192]	valid_0's rmse: 0.918084
# [193]	valid_0's rmse: 0.918078
# [194]	valid_0's rmse: 0.918045
# [195]	valid_0's rmse: 0.918037
# [196]	valid_0's rmse: 0.918015
# [197]	valid_0's rmse: 0.917999
# [198]	valid_0's rmse: 0.917984
# [199]	valid_0's rmse: 0.917979
# [200]	valid_0's rmse: 0.917965
# Validation error: 0.917965347997978
# Extracting fold...
# Preparing train...
# Preparing test...
# Training!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-1cce0ebd0728> in <module>()
#      43                     verbose_eval=True,
#      44                     feature_name=x_cols,
# ---> 45                     categorical_feature=x_cols)
#      46
#      47     test_y_pred = bst.predict(test_X)
#
# C:\Users\Anatoliy\Anaconda2\envs\py35\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     176     """construct booster"""
#     177     try:
# --> 178         booster = Booster(params=params, train_set=train_set)
#     179         if is_valid_contain_train:
#     180             booster.set_train_data_name(train_data_name)
#
# C:\Users\Anatoliy\Anaconda2\envs\py35\lib\site-packages\lightgbm\basic.py in __init__(self, params, train_set, model_file, silent)
#    1266             self.handle = ctypes.c_void_p()
#    1267             _safe_call(_LIB.LGBM_BoosterCreate(
# -> 1268                 train_set.construct().handle,
#    1269                 c_str(params_str),
#    1270                 ctypes.byref(self.handle)))
#
# C:\Users\Anatoliy\Anaconda2\envs\py35\lib\site-packages\lightgbm\basic.py in construct(self)
#     820                                 weight=self.weight, group=self.group, predictor=self._predictor,
#     821                                 silent=self.silent, feature_name=self.feature_name,
# --> 822                                 categorical_feature=self.categorical_feature, params=self.params)
#     823             if self.free_raw_data:
#     824                 self.data = None
#
# C:\Users\Anatoliy\Anaconda2\envs\py35\lib\site-packages\lightgbm\basic.py in _lazy_init(self, data, label, max_bin, reference, weight, group, predictor, silent, feature_name, categorical_feature, params)
#     624             self.pandas_categorical = reference.pandas_categorical
#     625             categorical_feature = reference.categorical_feature
# --> 626         data, feature_name, categorical_feature, self.pandas_categorical = _data_from_pandas(data, feature_name, categorical_feature, self.pandas_categorical)
#     627         label = _label_from_pandas(label)
#     628         self.data_has_header = False
#
# C:\Users\Anatoliy\Anaconda2\envs\py35\lib\site-packages\lightgbm\basic.py in _data_from_pandas(data, feature_name, categorical_feature, pandas_categorical)
#     256             msg = """DataFrame.dtypes for data must be int, float or bool. Did not expect the data types in fields """
#     257             raise ValueError(msg + ', '.join(bad_fields))
# --> 258         data = data.values.astype('float')
#     259     else:
#     260         if feature_name == 'auto':
#
# KeyboardInterrupt:

# %%
# !telegram-send "Validation finished. Results: $results."
